# %%
import numpy as np

# %%
num_of_agents = 5 # num agents
T = 8 # timesteps
R = 0.5 # confidence bound

# %%
opinions = np.random.rand(num_of_agents) # init all agents to [0,1]

# %%
def get_A(x):
    opinions_over_time = np.array([opinions]*num_of_agents)
    mask = abs(opinions_over_time - opinions_over_time.T) < R
    A = np.zeros(num_of_agents)
    for i in range(num_of_agents):
        A[i] = np.mean(opinions[mask[i]])
    return(A)

# %%
opinions_over_time = np.zeros((T,num_of_agents))
opinions_over_time[0,:] = opinions
for t in range(T-1):
    opinions_over_time[t+1,:] = get_A(opinions_over_time[t,:])
opinions_over_time
# Out:
# array([[0.54884599, 0.42301404, 0.63257831, 0.28373996, 0.61702144],
#        [0.50103995, 0.50103995, 0.50103995, 0.50103995, 0.50103995],
#        [0.50103995, 0.50103995, 0.50103995, 0.50103995, 0.50103995],
#        [0.50103995, 0.50103995, 0.50103995, 0.50103995, 0.50103995],
#        [0.50103995, 0.50103995, 0.50103995, 0.50103995, 0.50103995],
#        [0.50103995, 0.50103995, 0.50103995, 0.50103995, 0.50103995],
#        [0.50103995, 0.50103995, 0.50103995, 0.50103995, 0.50103995],
#        [0.50103995, 0.50103995, 0.50103995, 0.50103995, 0.50103995]])
