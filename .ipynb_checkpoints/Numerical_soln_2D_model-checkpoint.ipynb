# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
rng = np.random.default_rng(7)

# %% [markdown]
# ## Helper Functions

# %%
def get_A(opinions, R, std, num_topics, num_agents):
    '''
    A function to return the average opinion within R of each opinion in a vector of opinions
    '''
    
    # Create a square matrix consisting of the opinions vector repeated num_of_agents times
    y=np.array([opinions]*num_agents)
    
    z=y-y.T # difference in opinions across all topics
    
    # Create matrix of boolean values indicating which opinions are within R of each opinion
    mask = np.linalg.norm(z,axis=1) < R
    print(mask)
    
    # Initialise averages matrix
    A = np.zeros((num_topics,num_agents))

    for i in range(num_agents):
        # Get average of opinions within R of opinion
        avg = np.mean(opinions[:,mask[i]],axis=1)
        A[:,i] = avg + rng.normal(0, std, size=avg.shape)
    
    return(A)

# %% [markdown]
# ## Multiple Topics

# %%
num_agents = 50
T = 10
num_topics = 3
R = 0.3 # confidence bound
std=0.03

# %%
X  = np.random.rand(num_agents * T * num_topics).reshape((T, num_topics, num_agents))

# %%
for t in range(T-1):
    tmp = get_A(X[t,:,:], R, std, num_topics, num_agents)
    X[t+1,:,:] = tmp;
    #print(tmp)

# Note: X[:,0,:].T[0] evolution of 1 agent in opinion on topic 0
# Out:
# [[ True False False ... False False False]
#  [False  True  True ... False False False]
#  [False  True  True ... False False  True]
#  ...
#  [False False False ...  True  True False]
#  [False False False ...  True  True False]
#  [False False  True ... False False  True]]
# [[ True False False ... False False False]
#  [False  True  True ... False False False]
#  [False  True  True ... False False False]
#  ...
#  [False False False ...  True  True False]
#  [False False False ...  True  True False]
#  [False False False ... False False  True]]
# [[ True False False ... False False False]
#  [False  True  True ... False False False]
#  [False  True  True ... False False False]
#  ...
#  [False False False ...  True  True False]
#  [False False False ...  True  True False]
#  [False False False ... False False  True]]
# [[ True False False ... False False False]
#  [False  True  True ... False False False]
#  [False  True  True ... False False False]
#  ...
#  [False False False ...  True  True False]
#  [False False False ...  True  True False]
#  [False False False ... False False  True]]
# [[ True False False ... False False False]
#  [False  True  True ... False False False]
#  [False  True  True ... False False False]
#  ...
#  [False False False ...  True  True False]
#  [False False False ...  True  True False]
#  [False False False ... False False  True]]
# [[ True False False ... False False False]
#  [False  True  True ... False False False]
#  [False  True  True ... False False False]
#  ...
#  [False False False ...  True  True False]
#  [False False False ...  True  True False]
#  [False False False ... False False  True]]
# [[ True False False ... False False False]
#  [False  True  True ... False False False]
#  [False  True  True ... False False False]
#  ...
#  [False False False ...  True  True False]
#  [False False False ...  True  True False]
#  [False False False ... False False  True]]
# [[ True False False ... False False False]
#  [False  True  True ... False False  True]
#  [False  True  True ... False False  True]
#  ...
#  [False False False ...  True  True False]
#  [False False False ...  True  True False]
#  [False  True  True ... False False  True]]
# [[ True False False ... False False False]
#  [False  True  True ... False False  True]
#  [False  True  True ... False False  True]
#  ...
#  [False False False ...  True  True False]
#  [False False False ...  True  True False]
#  [False  True  True ... False False  True]]

# %%
X
# Out:
# array([[[0.74462046, 0.83399946, 0.53461784, 0.52557108],
#         [0.47832441, 0.94794544, 0.40544777, 0.53504121]],
#
#        [[0.60160313, 0.83399946, 0.60160313, 0.60160313],
#         [0.4729378 , 0.94794544, 0.4729378 , 0.4729378 ]],
#
#        [[0.60160313, 0.83399946, 0.60160313, 0.60160313],
#         [0.4729378 , 0.94794544, 0.4729378 , 0.4729378 ]],
#
#        [[0.60160313, 0.83399946, 0.60160313, 0.60160313],
#         [0.4729378 , 0.94794544, 0.4729378 , 0.4729378 ]],
#
#        [[0.60160313, 0.83399946, 0.60160313, 0.60160313],
#         [0.4729378 , 0.94794544, 0.4729378 , 0.4729378 ]],
#
#        [[0.60160313, 0.83399946, 0.60160313, 0.60160313],
#         [0.4729378 , 0.94794544, 0.4729378 , 0.4729378 ]]])

# %%
X[0,:,:][:,np.array([True, True, False, False])]
# Out:
# array([[0.74462046, 0.83399946],
#        [0.47832441, 0.94794544]])

# %%
y=np.array([X[0,:,:]]*X[0,:,:].shape[1])
z=y-y.T
z
# Out:
# array([[[ 0.        ,  0.089379  , -0.21000262, -0.21904938],
#         [ 0.        ,  0.46962103, -0.07287664,  0.0567168 ]],
#
#        [[-0.089379  ,  0.        , -0.29938162, -0.30842838],
#         [-0.46962103,  0.        , -0.54249766, -0.41290423]],
#
#        [[ 0.21000262,  0.29938162,  0.        , -0.00904676],
#         [ 0.07287664,  0.54249766,  0.        ,  0.12959344]],
#
#        [[ 0.21904938,  0.30842838,  0.00904676,  0.        ],
#         [-0.0567168 ,  0.41290423, -0.12959344,  0.        ]]])

# %%
np.sqrt(z[:,0]**2 + z[:,1]**2)
# Out:
# array([[0.        , 0.36135055, 0.49389212, 0.5809905 ],
#        [0.36135055, 0.        , 0.37290463, 0.34617191],
#        [0.49389212, 0.37290463, 0.        , 0.16297846],
#        [0.5809905 , 0.34617191, 0.16297846, 0.        ]])

# %%
mask = np.linalg.norm(z,axis=1) < R
mask
# Out:
# array([[ True, False, False, False],
#        [False,  True, False, False],
#        [False, False,  True,  True],
#        [False, False,  True,  True]])

# %%
mask[3]
# Out:
# array([False, False,  True,  True])

# %%
print(X[0,:,:][:,mask[3]])
np.mean(X[0,:,:][:,mask[3]],axis=1)
# Out:
# [[0.26753676 0.01087264]
#  [0.48834739 0.51326001]]
# array([0.1392047, 0.5008037])

# %%
# Evolution of agents' opinion regarding topics 0 and 1
fig, ax = plt.subplots(1,3,figsize=(10,4))
for i in range(num_agents):
    ax[0].plot(np.arange(T), X[:,0,:].T[i])
    ax[1].plot(np.arange(T), X[:,1,:].T[i])
    ax[2].plot(np.arange(T), X[:,2,:].T[i])

# %%
fig, ax = plt.subplots(1,1,figsize=(5,4))
ax.scatter(X[T-1,1,:], X[T-1,2,:])

# %% [markdown]
# ## One topic + Political Shocks

# %%
num_agents = 50
T = 10
num_topics = 1
R = 0.3 # confidence bound

# %%
X  = np.random.rand(num_agents * T * num_topics).reshape((T, num_topics, num_agents))
avg_opinion = np.zeros((num_topics,T))
t_shock = np.randint(T)

# %%
for t in range(T-1):
    if(t = t_shock):
        
        
    X[t+1,0,:] = get_A(X[t,0,:],R,num_agents)

# %%
opinions_1.sort()

# Initialising matrix of opinions over time
opinions_over_time = np.zeros((Timesteps, num_of_agents))
opinions_over_time[0,:] = opinions_1
for t in range(Timesteps-1):
    opinions_over_time[t+1,:] = get_A(opinions_over_time[t,:],R)

opinions_over_time

extremes_high = (opinions_over_time > 0.8)
extremes_low = (opinions_over_time < 0.2)
# extremes = opinions_over_time[mask]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 opinions_1.sort()
#       3 # Initialising matrix of opinions over time
#       4 opinions_over_time = np.zeros((Timesteps, num_of_agents))
#
# NameError: name 'opinions_1' is not defined

# %%
opinions_2.sort()

# Initialising matrix of opinions over time
opinions_over_time_2 = np.zeros((Timesteps, num_of_agents))
opinions_over_time_2[0,:] = opinions_2
for t in range(Timesteps-1):
    opinions_over_time_2[t+1,:] = get_A(opinions_over_time_2[t,:],R)
opinions_over_time_2
